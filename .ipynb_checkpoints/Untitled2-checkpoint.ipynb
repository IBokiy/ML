# %%
import numpy as np 
import pandas as pd 

import seaborn as sns                                   
import matplotlib as mpl
import matplotlib.pyplot as plt

from sklearn.metrics import silhouette_score, f1_score, confusion_matrix, classification_report, roc_auc_score,roc_curve, log_loss

# %% [markdown]
# ## Load dataset

# %% [markdown]
# Variable	Definition	Key
# survival	Survival	0 = No, 1 = Yes
# pclass	    Ticket class	1 = 1st, 2 = 2nd, 3 = 3rd
# sex	        Sex
# Age	        Age in years
# sibsp	    # of siblings / spouses aboard the Titanic
# parch	    # of parents / children aboard the Titanic
# ticket	    Ticket number
# fare	    Passenger fare
# cabin	    Cabin number
# embarked	Port of Embarkation	 C = Cherbourg, Q = Queenstown, S = Southampton

# %%
titanic = pd.read_csv('data/titanic.csv')

# %%
titanic.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
print(f'''Number of rows {titanic.shape[0]} and number of colums {titanic.shape[1]}.''')
# Out:
# Number of rows 891 and number of colums 12.

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ##### .info() shows important information about the data like datatypes,column names, and number of null values.Here in this dataset we can see we have null/missing values in 'Age', 'Embarked' and 'Cabin' columns.

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #### .describe() method provides a statistical summary of the data in your DataFrame. It provides the following information for numerical columns:
#
# Count: the number of non-null values.
# Mean: the average value.
# Standard Deviation: the measure of the spread of data.
# Minimum: the minimum value.
# 25th percentile: the value below which 25% of the data falls.
# Median: the middle value, separating the higher and lower halves of the data.
# 75th percentile: the value below which 75% of the data falls.
# Maximum: the maximum value.

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
sns.countplot(x='Pclass', data=titanic)
titanic['Pclass'].mode()
# Out:
# 0    3
# Name: Pclass, dtype: int64

# %% [markdown]
# Conclusion of above plot: more people were there in class 3 as compared to class 1 and class 2

# %%
sns.countplot(x='Survived', data=titanic)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# Conclusion of above plot: More people died i.e. 0 and less people survived i.e. 1 in this ship.

# %%
sns.countplot(x='Pclass', hue='Survived', data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Conclusion of above plot: Most of the people in class 1. And majority of the people died were from class 3.

# %%
sns.countplot(x='Sex', hue='Survived', data=titanic)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Conclusion of above plot: The no of Males were more than female. But more female survived.

# %%
sns.countplot(x='Embarked',hue='Survived',data=titanic)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# Conclusion of above plot: People who embarked from S and Q were most likely to not survive and People who embarked from C had more chance of survival.

# %%
sns.violinplot(x='Pclass',y='Sex',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Sex'>

# %% [markdown]
# Conclusion of above plot: There were more Female in Pclass 1 than Male in Pclass 1. Also there were more Male in Pclass 3 than Female in same class.

# %%
sns.violinplot(x='Pclass', data=titanic)
# Out:
# <Axes: xlabel='Pclass'>

# %% [markdown]
# Conclusion of above plot: Maximum people were in Pclass 3 followed by Pclass 1 and then least in Pclass 2.

# %%
sns.violinplot(x='Pclass',y='Sex',hue='Survived',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Sex'>

# %% [markdown]
# Conclusion of above plot: Male and Female in Pclass 3 did not survive the most.

# %%
sns.barplot(x='Pclass',y='Fare',data=titanic)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# Conclusion of above plot: Pclass 1 had the highest fare then Pclass 2 followed by Pclass 3.

# %%
sns.stripplot(x='Embarked', y='Fare', data=titanic)
# Out:
# <Axes: xlabel='Embarked', ylabel='Fare'>

# %% [markdown]
# Conclusion of above plot: Maximum fare was of people who embarked from C then from S followed by Q.

# %%
plt.figure(figsize=(15,6))
corr = titanic.corr(numeric_only=True)
corr = corr.drop('PassengerId', axis=1)
corr = corr.drop('PassengerId', axis=0)

sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Conclusion of above plot: The heatmap of the correlation matrix indicates the magnitude of the correlations (positive or negative) between values. Since the largest negative correlation for Survived is observed between the values of Survived and Pclass, let's look at this relationship in more detail.

# %%
group = titanic.groupby(['Pclass', 'Survived'])
pclass_survived = group.size().unstack()
 

sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.pairplot(titanic)

# %% [markdown]
# Plot distribution of values in points column using histogram.

# %%
titanic['Parch'].plot(kind='hist', edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Plot distribution of values in points column.

# %%
titanic['Parch'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Missing value treatment

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
